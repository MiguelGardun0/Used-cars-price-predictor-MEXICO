# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns
from xgboost import XGBClassifier
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import ColumnTransformer

# %%
df = pd.read_csv("sources/vehicles.csv", nrows=10000,index_col=0)
df.tail()
# Out:
#                                                           url   region  \
# id
# 7316825923  https://phoenix.craigslist.org/evl/ctd/d/mesa-...  phoenix
# 7316825904  https://phoenix.craigslist.org/evl/ctd/d/mesa-...  phoenix
# 7316825646  https://phoenix.craigslist.org/evl/ctd/d/mesa-...  phoenix
# 7316825626  https://phoenix.craigslist.org/evl/ctd/d/mesa-...  phoenix
# 7316825372  https://phoenix.craigslist.org/evl/ctd/d/mesa-...  phoenix
#
#                                 region_url  price    year manufacturer  \
# id
# 7316825923  https://phoenix.craigslist.org  15999  2015.0          gmc
# 7316825904  https://phoenix.craigslist.org   6999  2012.0         ford
# 7316825646  https://phoenix.craigslist.org  24999  2015.0          ram
# 7316825626  https://phoenix.craigslist.org   7999  2011.0         ford
# 7316825372  https://phoenix.craigslist.org  10999  2012.0     chrysler
#
#                           model condition    cylinders fuel  ...       size  \
# id                                                           ...
# 7316825923         acadia sle-1      good  6 cylinders  gas  ...  full-size
# 7316825904  focus sel hatchback      good  4 cylinders  gas  ...   mid-size
# 7316825646        1500 big horn      good  8 cylinders  gas  ...  full-size
# 7316825626           fusion sel      good  4 cylinders  gas  ...  full-size
# 7316825372    200 s convertible  like new  6 cylinders  gas  ...   mid-size
#
#                    type paint_color  \
# id
# 7316825923          SUV         red
# 7316825904    hatchback      silver
# 7316825646       pickup      silver
# 7316825626        sedan        grey
# 7316825372  convertible       white
#
#                                                     image_url  \
# id
# 7316825923  https://images.craigslist.org/00Y0Y_iukNOte9S5...
# 7316825904  https://images.craigslist.org/00i0i_kWRkjnGmCZ...
# 7316825646  https://images.craigslist.org/00l0l_9KhJhGzJE5...
# 7316825626  https://images.craigslist.org/00101_az5R00dbXW...
# 7316825372  https://images.craigslist.org/00Y0Y_dm8XwXGMb9...
#
#                                                   description county state  \
# id
# 7316825923  2015 GMC Acadia SLE-1 Financing Available!!! 6...    NaN    az
# 7316825904  2012 Ford Focus SEL Hatchback Loaded!!! 4 CYL ...    NaN    az
# 7316825646  2015 Ram 1500 Quad Cab Big Horn HEMI!!! 8 CYL ...    NaN    az
# 7316825626  2011 Ford Fusion SEL Nicely Loaded!!! 4 CYL En...    NaN    az
# 7316825372  2012 Chrysler 200 S Hard Top Convertible Nicel...    NaN    az
#
#                   lat        long              posting_date
# id
# 7316825923  33.415592 -111.657979  2021-05-04T10:48:28-0700
# 7316825904  33.415592 -111.657937  2021-05-04T10:48:27-0700
# 7316825646  33.415592 -111.657915  2021-05-04T10:48:02-0700
# 7316825626  33.415628 -111.657958  2021-05-04T10:48:00-0700
# 7316825372  33.415628 -111.657894  2021-05-04T10:47:36-0700
#
# [5 rows x 25 columns]

# %%
for cat in CAT_FEATURES:
    df[cat] = df[cat].str.strip().str.replace(' ', '_').str.replace('-', '_').str.lower() 
    
df = df.dropna(subset=["model", "odometer", "year","price"]).copy()

CAT_FEATURES = [ "manufacturer", "model",  "condition", "cylinders","fuel","title_status","transmission", "drive", "size", "type", "paint_color"]
NUM_FEATURES = ["odometer", "year","age"]

y = np.log1p(df["price"])                            
X = df[CAT_FEATURES + NUM_FEATURES]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
df = df.drop(7315961634)
df= df[df['price'] > 100]
df["age"] = 2026 - df["year"]

# %%
for col in X[CAT_FEATURES].columns:
    print(f"{df[col].value_counts()}")
# Out:
# manufacturer
# ford               1641
# chevrolet          1436
# toyota              707
# jeep                489
# nissan              437
# honda               373
# gmc                 368
# ram                 354
# dodge               348
# kia                 274
# bmw                 268
# subaru              204
# lexus               190
# mercedes_benz       185
# hyundai             184
# acura               170
# volkswagen          160
# cadillac            157
# chrysler            135
# audi                134
# buick               120
# infiniti            119
# lincoln             103
# mazda                95
# volvo                72
# mitsubishi           55
# jaguar               54
# mini                 51
# rover                39
# pontiac              38
# alfa_romeo           34
# porsche              22
# tesla                20
# fiat                 18
# mercury              18
# saturn               14
# harley_davidson       5
# ferrari               2
# Name: count, dtype: int64
# model
# f_150                      231
# silverado_1500             149
# silverado                  113
# 1500                        91
# wrangler                    77
#                           ...
# xc90_r_design                1
# express_2500_cargo_van       1
# silverado_1500_ls            1
# 1992_camaro                  1
# 2500_tradesman_crew_cab      1
# Name: count, Length: 2351, dtype: int64
# condition
# good         2890
# excellent    1544
# like_new      504
# fair          157
# new            35
# salvage         8
# Name: count, dtype: int64
# cylinders
# 6_cylinders     2432
# 4_cylinders     1991
# 8_cylinders     1804
# 3_cylinders       45
# 5_cylinders       34
# 10_cylinders      29
# other             28
# 12_cylinders       3
# Name: count, dtype: int64
# fuel
# gas         7962
# other        705
# diesel       527
# hybrid       102
# electric      50
# Name: count, dtype: int64
# title_status
# clean         8954
# rebuilt        205
# lien            57
# salvage         28
# missing         14
# parts_only       1
# Name: count, dtype: int64
# transmission
# automatic    7002
# other        1836
# manual        542
# Name: count, dtype: int64
# drive
# 4wd    3222
# fwd    2261
# rwd    1293
# Name: count, dtype: int64
# size
# full_size      1357
# mid_size        783
# compact         270
# sub_compact      47
# Name: count, dtype: int64
# type
# suv            1948
# sedan          1896
# pickup         1181
# truck           808
# other           548
# coupe           344
# hatchback       300
# wagon           264
# van             177
# convertible     142
# mini_van        114
# bus              31
# offroad          30
# Name: count, dtype: int64
# paint_color
# white     2190
# black     1372
# silver    1179
# red        923
# blue       745
# grey       584
# green      188
# custom     184
# brown      148
# yellow      51
# orange      44
# purple      13
# Name: count, dtype: int64

# %%
X.tail()
# Out:
#            manufacturer                model condition    cylinders fuel  \
# id
# 7316825923          gmc         acadia_sle_1      good  6_cylinders  gas
# 7316825904         ford  focus_sel_hatchback      good  4_cylinders  gas
# 7316825646          ram        1500_big_horn      good  8_cylinders  gas
# 7316825626         ford           fusion_sel      good  4_cylinders  gas
# 7316825372     chrysler    200_s_convertible  like_new  6_cylinders  gas
#
#            title_status transmission drive       size         type  \
# id
# 7316825923        clean    automatic   fwd  full_size          suv
# 7316825904        clean    automatic   fwd   mid_size    hatchback
# 7316825646        clean    automatic   rwd  full_size       pickup
# 7316825626        clean    automatic   fwd  full_size        sedan
# 7316825372        clean    automatic   fwd   mid_size  convertible
#
#            paint_color  odometer    year   age
# id
# 7316825923         red  135000.0  2015.0  11.0
# 7316825904      silver  153000.0  2012.0  14.0
# 7316825646      silver  107000.0  2015.0  11.0
# 7316825626        grey  121000.0  2011.0  15.0
# 7316825372       white   94000.0  2012.0  14.0

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9432 entries, 7316814884 to 7316825372
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   manufacturer  9093 non-null   object
#  1   model         9432 non-null   object
#  2   condition     5138 non-null   object
#  3   cylinders     6366 non-null   object
#  4   fuel          9346 non-null   object
#  5   title_status  9259 non-null   object
#  6   transmission  9380 non-null   object
#  7   drive         6776 non-null   object
#  8   size          2457 non-null   object
#  9   type          7783 non-null   object
#  10  paint_color   7621 non-null   object
#  11  odometer      9432 non-null   float64
#  12  year          9432 non-null   float64
#  13  age           9432 non-null   float64
# dtypes: float64(3), object(11)
# memory usage: 1.1+ MB

# %%
plt.figure(figsize=(10, 6))
sns.histplot(y, kde=True, bins=50)
plt.title('Distribution of Log(1+Price)')
plt.xlabel('Log(1+Price)')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(y)
plt.title('Boxplot of Log(1+Price)')
plt.ylabel('Log(1+Price)')
plt.show()

# %%
print(y.describe())
print(f"Skewness: {y.skew()}")
print(f"Kurtosis: {y.kurt()}")
# Out:
# count    9432.000000
# mean        9.733986
# std         0.865347
# min         5.247024
# 25%         9.305287
# 50%         9.952087
# 75%        10.308953
# max        12.343663
# Name: price, dtype: float64
# Skewness: -1.4251074376978645
# Kurtosis: 3.178460739927677

# %%
duplicated_indices = X[X.duplicated()].index
print(y.loc[duplicated_indices])
# Out:
# id
# 7316788498    10.586357
# 7316422333    10.422013
# 7316368518    10.239638
# 7316160104    10.308653
# 7315826530    10.239638
#                 ...
# 7316848600     6.216606
# 7316838408    10.085642
# 7316837499     6.216606
# 7316834102    10.462846
# 7316829724     6.216606
# Name: price, Length: 3257, dtype: float64

# %%
for num in NUM_FEATURES:
    print(X[num].describe())
# Out:
# count    9.432000e+03
# mean     8.547128e+04
# std      1.318560e+05
# min      0.000000e+00
# 25%      2.765375e+04
# 50%      6.800000e+04
# 75%      1.234560e+05
# max      1.000000e+07
# Name: odometer, dtype: float64
# count    9432.000000
# mean     2012.163168
# std         9.414341
# min      1922.000000
# 25%      2010.000000
# 50%      2015.000000
# 75%      2018.000000
# max      2022.000000
# Name: year, dtype: float64
# count    9432.000000
# mean       13.836832
# std         9.414341
# min         4.000000
# 25%         8.000000
# 50%        11.000000
# 75%        16.000000
# max       104.000000
# Name: age, dtype: float64

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(X.odometer)
plt.title('Boxplot of Odometer')
plt.ylabel('kms')
plt.show()

# %%
X = X[X["odometer"]<999998]

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(X.odometer)
plt.title('Boxplot of Odometer')
plt.ylabel('kms')
plt.show()

# %%
X[X["odometer"]>500000]
# Out:
#            manufacturer                     model condition    cylinders  \
# id
# 7304161888          NaN                   kw_t800       NaN          NaN
# 7303573579        volvo  coe_semi_w/18_feet_frame       NaN  6_cylinders
#
#               fuel title_status transmission drive       size   type  \
# id
# 7304161888  diesel        clean       manual   NaN        NaN    NaN
# 7303573579  diesel        clean       manual   rwd  full_size  truck
#
#            paint_color  odometer    year   age
# id
# 7304161888       white  771000.0  2005.0  21.0
# 7303573579       white  590000.0  1995.0  31.0

# %%
sns.boxplot(x=X.manufacturer, y=y)
plt.title('Manufacturer vs Price')
plt.ylabel('Price')
plt.xlabel('Manufacturer')
plt.show()

# %%
sns.heatmap(X[NUM_FEATURES].corr())
# Out:
# <Axes: >

# %%
#Numeric
num_pipe = Pipeline([
    ('scaler',StandardScaler())
])

# %%
#Categocial 
cat_pipe = Pipeline([
    ('imputer', SimpleImputer(strategy='constant', fill_value='Unknown')),
     ('encoder', OneHotEncoder(
                    min_frequency=10, 
                    handle_unknown='infrequent_if_exist',
                    sparse_output=False))
])

# %%
preprocessor = ColumnTransformer(
    transformers=[
        ('num', num_pipe, NUM_FEATURES),
        ('cat', cat_pipe, CAT_FEATURES)])

# %%
#final pipeline
full_pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('model', XGBClassifier())
], memory='./cache_dir')

# %%
full_pipeline.fit()
